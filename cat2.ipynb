# %%
# import required libraries
import cv2
import numpy as np

# Read input image
# img = cv2.imread("audi.jpg")
img = cv2.imread("cv_cat2.png")

# convert input image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# read haarcascade for number plate detection
cascade = cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')

# Detect license number plates
plates = cascade.detectMultiScale(gray, 1.2, 5)
print('Number of detected license plates:', len(plates))

# loop over all plates
for (x,y,w,h) in plates:
   
   # draw bounding rectangle around the license number plate
   cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
   gray_plates = gray[y:y+h, x:x+w]
   color_plates = img[y:y+h, x:x+w]
   
   # save number plate detected
   cv2.imwrite('Numberplate.jpg', gray_plates)
   cv2.imshow('Number Plate', gray_plates)
   cv2.imshow('Number Plate Image', img)
   cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of detected license plates: 0

# %%
# !pip install opencv-python-headless
# !pip install pytesseract
# Out:
# ...
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.0 MB 2.6 MB/s eta 0:00:15
#    ---------------------------------------- 0.3/38.0 MB 3.8 MB/s eta 0:00:10
#     --------------------------------------- 0.5/38.0 MB 3.9 MB/s eta 0:00:10
#     --------------------------------------- 0.8/38.0 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.0/38.0 MB 4.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.0 MB 4.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.4/38.0 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/38.0 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/38.0 MB 4.4 MB/s eta 0:00:09
#    -- ------------------------------------- 2.0/38.0 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.2/38.0 MB 4.3 MB/s eta 0:00:09
# ...

# %%
import cv2
import pytesseract

# Load the handwritten image
image_path = 'cv_cat2.png'
image = cv2.imread(image_path)

# Convert the image to grayscale for better text detection
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load a pre-trained Haar cascade for text detection
text_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')

# Detect text regions using the Haar cascade
text_regions = text_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Loop through the detected text regions and extract text using Tesseract
for (x, y, w, h) in text_regions:
    # Crop the region containing text
    text_region = gray[y:y + h, x:x + w]

    # Perform OCR on the cropped text region
    detected_text = pytesseract.image_to_string(text_region, config='--psm 6')

    # Print the detected text
    print(detected_text)

# Display the original image with text regions marked
for (x, y, w, h) in text_regions:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2.imshow('Handwritten Text Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the handwritten image
image_path = 'cv_cat2.png'
image = cv2.imread(image_path)

# Convert the image to grayscale for better text detection
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load a pre-trained Haar cascade for text detection
text_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')

# Detect text regions using the Haar cascade
text_regions = text_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Initialize an image to display the extracted text
result_image = image.copy()

# Loop through the detected text regions and extract text using Tesseract
for (x, y, w, h) in text_regions:
    # Crop the region containing text
    text_region = gray[y:y + h, x:x + w]

    # Perform OCR on the cropped text region
    detected_text = pytesseract.image_to_string(text_region, config='--psm 6')

    # Print the detected text
    print(detected_text)

    # Draw the detected text on the result image
    cv2.putText(result_image, detected_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# Display the original image with text regions marked and the extracted text
cv2.imshow('Handwritten Text Detection', result_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import pytesseract

# Load the handwritten image
image_path = 'img1.png'
image = cv2.imread(image_path)

# Convert the image to grayscale for better text detection
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load a pre-trained Haar cascade for text detection
text_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')

# Detect text regions using the Haar cascade
text_regions = text_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Check if text regions are detected
if len(text_regions) == 0:
    print("No text regions detected.")
else:
    # Loop through the detected text regions and extract text using Tesseract
    for (x, y, w, h) in text_regions:
        # Crop the region containing text
        text_region = gray[y:y + h, x:x + w]

        # Perform OCR on the cropped text region
        detected_text = pytesseract.image_to_string(text_region, config='--psm 6')

        # Print the detected text
        print("Detected Text:", detected_text)

# Display the original image with text regions marked
for (x, y, w, h) in text_regions:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2.imshow('Handwritten Text Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# No text regions detected.

# %%
import cv2
import pytesseract
#pytesseract.pytesseract.tesseract_cmd = "C:\Users\Sarika\Downloads\tesseract-ocr-w64-setup-5.3.3.20231005" 
# Load the handwritten image
image_path = 'cv_cat2.png'
image = cv2.imread(image_path)

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load a pre-trained Haar cascade for text detection
text_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')

# Detect text regions using the Haar cascade
text_regions = text_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Loop through the detected text regions and extract text using Tesseract
for (x, y, w, h) in text_regions:
    # Crop the region containing text
    text_region = gray[y:y + h, x:x + w]

    # Perform OCR on the cropped text region
    detected_text = pytesseract.image_to_string(text_region, config='--psm 6')

    # Print the recognized text
    print(detected_text)

# Display the original image with text regions marked
for (x, y, w, h) in text_regions:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2.imshow('Handwritten Text Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# !pip install easyocr==1.6.2
# Out:
# ...
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#       --------------------------------------- 0.1/5.7 MB 2.2 MB/s eta 0:00:03
#      - -------------------------------------- 0.2/5.7 MB 2.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/5.7 MB 2.0 MB/s eta 0:00:03
#      -- ------------------------------------- 0.4/5.7 MB 2.0 MB/s eta 0:00:03
#      --- ------------------------------------ 0.5/5.7 MB 2.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.7/5.7 MB 2.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.8/5.7 MB 2.4 MB/s eta 0:00:03
#      ------ --------------------------------- 1.0/5.7 MB 2.5 MB/s eta 0:00:02
#      ------- -------------------------------- 1.1/5.7 MB 2.7 MB/s eta 0:00:02
#      -------- ------------------------------- 1.3/5.7 MB 2.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.5/5.7 MB 2.8 MB/s eta 0:00:02
# ...

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np

# read image
image_path = 'cv_cat2.png'

img = cv2.imread(image_path)

# instance text detector
reader = easyocr.Reader(['en'], gpu=False)

# detect text on image
text_ = reader.readtext(img)

threshold = 0.25
# draw bbox and text
for t_, t in enumerate(text_):
    print(t)

    bbox, text, score = t

    if score > threshold:
        cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 5)
        cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete([[20, 26], [196, 26], [196, 126], [20, 126]], 'Last', 0.9537613987922668)
# ([[22, 150], [124, 150], [124, 226], [22, 226]], 'We', 0.9974950368974568)
# ([[150, 152], [354, 152], [354, 248], [150, 248]], 'had ^', 0.6754761151125506)
# ([[28, 268], [162, 268], [162, 324], [28, 324]], 'Team', 0.946197509765625)
# ([[226.0866267888802, 6.034810934330844], [490.8257770193579, 57.9626002138934], [464.9133732111198, 160.96518906566916], [200.17422298064213, 108.0373997861066]], 'Wedmsdry', 0.5223538693712881)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# d:\SEM 9\computer vision lab\cat2\cat2.ipynb Cell 8 line 2
# ...
